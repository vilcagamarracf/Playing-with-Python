# %% [markdown]
# <h1 align="center"> Manejo de archivos <code>csv</code></h1>
# <h2 align="center"> Aplicación con información de datos de precipitación 📈</h2>

# %% [markdown]
# **Objetivo**
#
# En la presente libreta veremos el uso de la librería `pandas` para el manejo de archivos `.csv` (delimitado por comas) usando datos de precipitación de manera aplicativa.

# %%
# Realizar un cambio de ruta a la carpeta con csv's

import os 
print('Ruta inicial:\n', os.getcwd()) # Antes

# cambio a carpeta con csv's en local
os.chdir('E:\Desktop\prueba') 

print('Ruta final:\n', os.getcwd()) # Después

# Listar archivos en la carpeta contenedora de csv's
os.listdir()
# Out:
# Ruta inicial:
#  C:\Users\LENOVO\Documents\GitHub-repos\Playing-with-colab\jupyter_notebooks
# Ruta final:
#  E:\Desktop\prueba
# ['ALTAMIZA.csv',
#  'BARRIOS.csv',
#  'BERNAL.csv',
#  'CANCHAQUE.csv',
#  'CHALACO.csv',
#  'CHIGNIA.csv',
#  'prueba.py']

# %% [markdown]
# ## Lectura de archivos `csv`

# %% [markdown]
# Los siguientes archivos `.csv` se obtuvieron del portal ANA y presentan información sobre estaciones climatológicas de la cuenca Piura.
#
# A continuación veremos dos casos:
# - Cuando se tiene un archivo csv de manera ordenada (tratada)
# - Cuando se tiene un archivo por ordenar

# %% [markdown]
# Importamos la librería `pandas` para el procesamiento de datos y la librería `matplotlib` para la visualización de los mismos.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Caso 1: Archivo `csv` ordenado, las fechas presentan buen formato para editar**

# %%
# Importando archivo csv
est_ALTAMIZA = pd.read_csv('ALTAMIZA.csv')

# Tipo de estac_1
print(f'tipo: {type(est_ALTAMIZA)}') # DataFrame

display(est_ALTAMIZA.head())
# Out:
# tipo: <class 'pandas.core.frame.DataFrame'>
#    ESTACION                                     OPERADOR  \
# 0  ALTAMIZA  SERVICIO NACIONAL METEOROLOGÍA E HIDROLOGÍA
# 1  ALTAMIZA  SERVICIO NACIONAL METEOROLOGÍA E HIDROLOGÍA
# 2  ALTAMIZA  SERVICIO NACIONAL METEOROLOGÍA E HIDROLOGÍA
# 3  ALTAMIZA  SERVICIO NACIONAL METEOROLOGÍA E HIDROLOGÍA
# 4  ALTAMIZA  SERVICIO NACIONAL METEOROLOGÍA E HIDROLOGÍA
#
#                   VARIABLE       FECHA  VALOR UNIDADMEDIDA
# 0  PRECIPITACION ACU 12HOR  1972-12-01    0.0            m
# 1  PRECIPITACION ACU 12HOR  1972-12-02    0.0           mm
# 2  PRECIPITACION ACU 12HOR  1972-12-03    0.0           mm
# 3  PRECIPITACION ACU 12HOR  1972-12-04    0.0           mm
# 4  PRECIPITACION ACU 12HOR  1972-12-05    4.1           mm

# %%
# Eliminamos información irrevelante
est_ALTAMIZA = est_ALTAMIZA.iloc[:,3:].drop('UNIDADMEDIDA', axis=1)
est_ALTAMIZA.head()
# Out:
#         FECHA  VALOR
# 0  1972-12-01    0.0
# 1  1972-12-02    0.0
# 2  1972-12-03    0.0
# 3  1972-12-04    0.0
# 4  1972-12-05    4.1

# %%
# Visualizar el 'tipo' de cada columna
est_ALTAMIZA.dtypes
# Out:
# FECHA     object
# VALOR    float64
# dtype: object

# %% [markdown]
# Nótese el tipo `object` de la columna `FECHA`. Esto indica que cada valor en dicha columna es un `string` (cadena de texto) y lo preferible para manejar datos de series de tiempo es usar un tipo `datetime64`.

# %%
est_ALTAMIZA.FECHA = pd.to_datetime(est_ALTAMIZA.FECHA)
est_ALTAMIZA.dtypes
# Out:
# FECHA    datetime64[ns]
# VALOR           float64
# dtype: object

# %%
# Volvemos la columna 'FECHA' como índice del DataFrame para su mejor manejo
est_ALTAMIZA.set_index('FECHA', inplace=True)
est_ALTAMIZA.head()
# Out:
#             VALOR
# FECHA
# 1972-12-01    0.0
# 1972-12-02    0.0
# 1972-12-03    0.0
# 1972-12-04    0.0
# 1972-12-05    4.1

# %%
# Visualización básica
#import matplotlib.pyplot as plt

plt.figure(1, figsize=(15,7))
plt.plot(est_ALTAMIZA.VALOR, marker='o', color='black',ms=2, linestyle='none')
plt.title('Estación Altamiza')
plt.xlabel('Años')
plt.ylabel('Precipitación (mm)')
plt.grid();

# %% [markdown]
# Véase los espacios con datos faltantes.
#
# Una vez establecido las fechas como `index`, es posible manejarlas con mayor flexibilidad. A continuación, un ejemplo sobre el filtrado por años y su visualización.

# %%
# Datos del año 1976
est_ALTAMIZA.loc['1976',['VALOR']].head(7)
# Out:
#             VALOR
# FECHA
# 1976-01-01    0.0
# 1976-01-02    1.2
# 1976-01-03    7.0
# 1976-01-04    5.6
# 1976-01-05    1.1
# 1976-01-06   18.6
# 1976-01-07   10.2

# %%
# Visualización del año 1984 de dos maneras: Línea y Puntos
plt.figure(1, figsize=(15,5))
plt.plot(est_ALTAMIZA.loc['1984',['VALOR']], color='black',ms=2, linestyle='-')
plt.title('Estación Altamiza - Información del año 1984')
plt.xlabel('Años'), plt.ylabel('Precipitación (mm)')
plt.margins(0.02)
plt.grid()

plt.figure(2, figsize=(15,5))
plt.plot(est_ALTAMIZA.loc['1984',['VALOR']], marker='o', color='black',ms=2, linestyle='none')
plt.title('Estación Altamiza - Información del año 1984')
plt.xlabel('Años'), plt.ylabel('Precipitación (mm)')
plt.margins(0.02)
plt.grid()

# %% [markdown]
# Cuando se presentan datos faltantes (observable según fechas), al usar un estilo de línea para la visualización, ésta tiende a unir todos los puntos que representan datos, presentando así una falsa noción de no tener falta de datos.
# Por ello, se optó por puntos, siendo así notable los datos faltantes.

# %% [markdown]
# Y también es posible graficar todos los años mediante un bucle `for` como se ve a continuación:

# %%
# Generación de gráficas para cada año desde 1972-1975
years_list = [str(i) for i in range(1972, 1975+1)]  

for i in years_list:
    plt.figure(years_list.index(i)+1, figsize=(15,5))
    plt.plot(est_ALTAMIZA.loc[i,['VALOR']], marker='o', color='black',ms=2, linestyle='none')
#     plt.plot(est_ALTAMIZA.loc[i,['VALOR']], color='black',ms=2, linestyle='-')
    plt.title('Estación Altamiza - Información del año '+i)
    plt.xlabel('Años'), plt.ylabel('Precipitación (mm)')
    plt.margins(0.02)
    plt.grid()

# %% [markdown]
# Nótese cómo varían los ejes X de fechas, indicando así también cuando hay datos faltantes.

# %% [markdown]
# ----

# %% [markdown]
# ### Caso 2: Archivo `csv` en crudo, las fechas presentan un formato que requiere procesar

# %%
# Importando archivo csv
est_BARRIOS = pd.read_csv('BARRIOS.csv')
est_BARRIOS.head()
# Out:
#   ESTACION                                     OPERADOR  \
# 0  BARRIOS  SERVICIO NACIONAL METEOROLOGÍA E HIDROLOGÍA
# 1  BARRIOS  SERVICIO NACIONAL METEOROLOGÍA E HIDROLOGÍA
# 2  BARRIOS  SERVICIO NACIONAL METEOROLOGÍA E HIDROLOGÍA
# 3  BARRIOS  SERVICIO NACIONAL METEOROLOGÍA E HIDROLOGÍA
# 4  BARRIOS  SERVICIO NACIONAL METEOROLOGÍA E HIDROLOGÍA
#
#                   VARIABLE                 FECHA  VALOR UNIDADMEDIDA
# 0  PRECIPITACION ACU 12HOR  1973-09-03T00:00:00Z    0.0           mm
# 1  PRECIPITACION ACU 12HOR  1973-09-04T00:00:00Z    0.0           mm
# 2  PRECIPITACION ACU 12HOR  1973-09-05T00:00:00Z    0.0           mm
# 3  PRECIPITACION ACU 12HOR  1973-09-06T00:00:00Z    0.0           mm
# 4  PRECIPITACION ACU 12HOR  1973-09-07T00:00:00Z    0.0           mm

# %%
# Eliminamos información irrelevante
est_BARRIOS = est_BARRIOS.iloc[:,3:].drop('UNIDADMEDIDA', axis=1)
display(est_BARRIOS.head())

print(est_BARRIOS.dtypes)
# Out:
#                   FECHA  VALOR
# 0  1973-09-03T00:00:00Z    0.0
# 1  1973-09-04T00:00:00Z    0.0
# 2  1973-09-05T00:00:00Z    0.0
# 3  1973-09-06T00:00:00Z    0.0
# 4  1973-09-07T00:00:00Z    0.0
# FECHA     object
# VALOR    float64
# dtype: object

# %% [markdown]
# La columna `FECHA` presenta información de tiempo pero de tipo `object` (`string`) y un formato largo que contiene también información de zonas horarias. Es necesario modificarlo para su manejo.

# %% [markdown]
# Toca corregir el formato de fecha. Para ello, es necesario realizar ciertos cambios:
# 1. Convertir la columna `FECHA` de tipo `object` a `datetime64[ns]`.
# 2. Una vez en `datetime64[ns]` es posible aplicar una función del módulo `datetime` con el fin de modificarlo como `string` (darle un formato a gusto). Devolverá un `object` (`string`).
# 3. Realizar otra vez el Paso 1 para obtener un tipo `datetime64[ns]`.

# %%
# 1. Convertir a tipo fecha
est_BARRIOS.FECHA = pd.to_datetime(est_BARRIOS.FECHA) # devuelve a datetime64[ns] (tipo fecha)

# 2. Modificar el formato (convierte a string)
import datetime as dt
est_BARRIOS.FECHA = est_BARRIOS.FECHA.dt.strftime('%Y/%m/%d') # convierte a string según formato

# 3. Convertir otra vez a tipo fecha
est_BARRIOS.FECHA = pd.to_datetime(est_BARRIOS.FECHA)
display(est_BARRIOS.head())

print(est_BARRIOS.dtypes)
# Out:
#        FECHA  VALOR
# 0 1973-09-03    0.0
# 1 1973-09-04    0.0
# 2 1973-09-05    0.0
# 3 1973-09-06    0.0
# 4 1973-09-07    0.0
# FECHA    datetime64[ns]
# VALOR           float64
# dtype: object

# %% [markdown]
# Ahora volverlo `index`.

# %%
# Volver la columna FECHA como index
est_BARRIOS.set_index('FECHA', inplace=True)
display(est_BARRIOS.head())

print(est_BARRIOS.dtypes)
# Out:
#             VALOR
# FECHA
# 1973-09-03    0.0
# 1973-09-04    0.0
# 1973-09-05    0.0
# 1973-09-06    0.0
# 1973-09-07    0.0
# VALOR    float64
# dtype: object

# %%
# Visualización
import matplotlib.pyplot as plt

plt.figure(1,figsize=(15,7))

plt.plot(est_BARRIOS.VALOR, c='black', marker='.', linestyle='none', ms=5)
plt.title('Estación BARRIOS - Histórico de Precipitación')
plt.xlabel('Años'), plt.ylabel('Precipitación (mm)')
plt.grid();

# %% [markdown]
# ### Resumen

# %% [markdown]
# El proceso para iniciar a manejar fechas como índice queda resumido de la siguiente manera:

# %%
est_ALTAMIZA = pd.read_csv('ALTAMIZA.csv')
est_ALTAMIZA = est_ALTAMIZA.iloc[:,3:].drop('UNIDADMEDIDA', axis=1)
est_ALTAMIZA.FECHA = pd.to_datetime(est_ALTAMIZA.FECHA)
est_ALTAMIZA.set_index('FECHA', inplace=True)
est_ALTAMIZA.head()
# Out:
#             VALOR
# FECHA
# 1972-12-01    0.0
# 1972-12-02    0.0
# 1972-12-03    0.0
# 1972-12-04    0.0
# 1972-12-05    4.1

# %%
# DataFrame en blanco
grafica_ALTAMIZA = pd.DataFrame()

# Generar una lista de años para visualizar
years_list = [str(i) for i in range(1972, 1994+1)]  

# Select data for each year and concatenate with prices here 
for year in years_list:
    est_ALTAMIZA_meses = est_ALTAMIZA.loc[year, ['VALOR']].reset_index(drop=True)
    est_ALTAMIZA_meses.rename(columns={'VALOR': year}, inplace=True)
    grafica_ALTAMIZA = pd.concat([grafica_ALTAMIZA, est_ALTAMIZA_meses], axis=1)

# Plot prices
ax = grafica_ALTAMIZA.plot(figsize=(15,8))
ax.set(title='Estación Altamiza - Histórico de Precipitaciones registradas', 
       xlabel='Días del año', 
       ylabel='Precipitación [mm]');

# %% [markdown]
# Nótese cómo los datos nos indican el patrón que siguen las lluvias en dicho lugar. Por ahora
#
# Para mayor información sobre los argumentos disponibles en `pd.DataFrame.plot()`, revisar este [enlace](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html).

# %% [markdown]
# ----

# %% [markdown]
# ### Prueba

# %%
# Filtrando información por fechas específicas
display(est_ALTAMIZA.loc['1984-1',['VALOR']])

est_ALTAMIZA.loc['1984-1',['VALOR']].count()

# for i in range(1,12+1) :
#     print(est_ALTAMIZA.loc['1984-'+str(i),['VALOR']].count())
# Out:
#             VALOR
# FECHA
# 1984-01-01    0.0
# 1984-01-02    8.7
# 1984-01-03    7.2
# 1984-01-04    0.0
# 1984-01-05    0.0
# 1984-01-06    0.0
# 1984-01-07    0.0
# 1984-01-08    0.0
# 1984-01-09    0.0
# 1984-01-10    0.0
# 1984-01-11    0.0
# 1984-01-12    0.0
# 1984-01-13    0.0
# 1984-01-14    0.0
# 1984-01-15    0.0
# 1984-01-16    0.0
# 1984-01-17    0.1
# 1984-01-18    3.2
# 1984-01-19    4.6
# 1984-01-20    6.8
# 1984-01-21    4.5
# 1984-01-22   13.7
# 1984-01-23    7.4
# 1984-01-24    0.0
# 1984-01-25    0.0
# 1984-01-26    0.0
# 1984-01-27    0.0
# 1984-01-28    0.2
# 1984-01-29    0.8
# 1984-01-30    1.6
# 1984-01-31    3.1
# VALOR    31
# dtype: int64

# %%
est_ALTAMIZA_prueba = est_ALTAMIZA.asfreq('D')

est_ALTAMIZA_prueba['90D'] = est_ALTAMIZA_prueba.VALOR.rolling('90D').mean()
est_ALTAMIZA_prueba['360D'] = est_ALTAMIZA_prueba.VALOR.rolling('360D').mean()

ax = est_ALTAMIZA_prueba['1972':].plot(figsize=(12,6))
ax.set(title='Estación Altamiza');

# %%
est_ALTAMIZA_prueba = est_ALTAMIZA.asfreq('D')

est_ALTAMIZA_stats = est_ALTAMIZA_prueba.VALOR.rolling(360).agg(['mean', 'std'])
stats = est_ALTAMIZA_prueba.join(est_ALTAMIZA_stats)
stats.plot(subplots=True, figsize=(15,10));

# %%
# Resample, interpolate and inspect ozone data here
est_ALTAMIZA_prueba = est_ALTAMIZA.resample('D').interpolate()
est_ALTAMIZA_prueba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7821 entries, 1972-12-01 to 1994-04-30
# Freq: D
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   VALOR   7821 non-null   float64
# dtypes: float64(1)
# memory usage: 122.2 KB

# %%
# Create the rolling window
rolling = est_ALTAMIZA_prueba.rolling(360)['VALOR']

# Insert the rolling quantiles to the monthly returns
est_ALTAMIZA_prueba['q10'] = rolling.quantile(.1)
est_ALTAMIZA_prueba['q50'] = rolling.quantile(.5)
est_ALTAMIZA_prueba['q90'] = rolling.quantile(.9)

# Plot the data
est_ALTAMIZA_prueba.plot(figsize=(12,8))
plt.show()

# %%
est_ALTAMIZA_month = est_ALTAMIZA.asfreq('D')  # D=daily, M=monthly, y=yearly
ax = est_ALTAMIZA_month.plot(figsize=(12, 8))
ax.set(title='asds');

# %%
display(est_ALTAMIZA.info())

# Business day frequency
est_ALTAMIZA_business_day = est_ALTAMIZA.asfreq('B')
display(est_ALTAMIZA_business_day.info())

# Calendar day frequency
est_ALTAMIZA_day = est_ALTAMIZA.asfreq('D')
display(est_ALTAMIZA_day.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6934 entries, 1972-12-01 to 1994-04-30
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   VALOR   6934 non-null   float64
# dtypes: float64(1)
# memory usage: 366.4 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5586 entries, 1972-12-01 to 1994-04-29
# Freq: B
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   VALOR   4955 non-null   float64
# dtypes: float64(1)
# memory usage: 87.3 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7821 entries, 1972-12-01 to 1994-04-30
# Freq: D
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   VALOR   6934 non-null   float64
# dtypes: float64(1)
# memory usage: 122.2 KB
# None

# %% [markdown]
# Para obtener más información sobre `strings` de frecuencia, consultar el siguiente [link](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#offset-aliases)

# %% [markdown]
# -----

# %% [markdown]
# ### Visualización extra

# %% [markdown]
# **Haciendo un *zoom* entre fechas para visualización parcial de los datos (REVISAR)**

# %%
# print(est_BARRIOS.FECHA[estac_2['FECHA'] == '1987-01-01']) 
# print(est_BARRIOS.FECHA[estac_2['FECHA'] == '1990-01-01']) 

# ochentas = estac_2[4827:5920]

# plt.figure(1,figsize=(15,7))

# plt.plot(ochentas.FECHA, ochentas.VALOR, c='black', marker='.', linestyle='none', ms=5, alpha=0.5)
# plt.title('Precipitación Acumulada Mensual - Estación BARRIOS Fechas 1987 - 1990')
# plt.xlabel('Fechas'), plt.ylabel('Precipitación (mm)')
# # plt.margins(0.02)
# plt.grid();

# %%
# Making an ECDF: Empirical cumulative distribution function (ECDF)

import numpy as np
x = np.sort(estac_1.VALOR) # ordenamiento de menor a mayor
y = np.arange(1, len(x)+1) / len(x)

percentiles = np.array([2.5, 25, 50, 75, 97.5])

# Compute percentiles: ptiles_vers
ptiles_estac1 = np.percentile(estac_1.VALOR, percentiles)
ptiles_estac2 = np.percentile(estac_2.VALOR, percentiles)

plt.figure(1, figsize=(15,6))

plt.subplot(121)
plt.plot(x, y, marker='.', linestyle='none') # solo puntos
plt.plot(ptiles_estac1, percentiles/100, marker='D', color='red', linestyle='none')
plt.title('Estacion Altamiza')
plt.xlabel('Precipitación (mm)')
plt.ylabel('ECDF')
plt.grid()
plt.margins(0.02) # Keeps data off plot edges

plt.subplot(122)
x = np.sort(estac_2.VALOR) # ordenamiento de menor a mayor
y = np.arange(1, len(x)+1) / len(x)
plt.plot(x, y, marker='.', linestyle='none') # solo puntos
plt.plot(ptiles_estac2, percentiles/100, marker='D', color='red', linestyle='none')
plt.title('Estacion Barrios')
plt.xlabel('Precipitación (mm)')
plt.ylabel('ECDF')
plt.grid()
plt.margins(0.02); # Keeps data off plot edges

# %%
max_rain = estac_1.VALOR.max() 

estac_1['point_type'] = ['Día con mayor lluvia' if VALOR == max_rain else 'Otros' for VALOR in estac_1.VALOR]

sns.scatterplot(x = 'FECHA',
                y = 'VALOR',
                hue = 'point_type',
                data = estac_1)
plt.show()

# %%
# Filter dataset to the year 1976

plt.figure(1, figsize=(10,6))
plt.title('Kernel Density Estimation (KDE)')
sns.kdeplot(
    estac_1[estac_1.Año == 1976].VALOR,
    # Shade under kde and add a helpful label
    shade=True,
    label='1976')

# Filter dataset to everything except the year 2012
sns.kdeplot(
    estac_1[estac_1.Año != 1976].VALOR,
    # Again, shade under kde and add a helpful label
    shade=True,
    label='Otros años')
plt.legend()
plt.show()

# %%
import seaborn as sns

plt.figure(1, figsize=(15,6))
# Change to use relplot() instead of scatterplot()
sns.relplot(x="FECHA", y="VALOR", data=estac_1, kind="scatter", alpha=0.4)

# Show plot
plt.show()

# %%
# ECDF: Empirical cumulative distribution function (ECDF)

import numpy as np
x = np.sort(estac_1.VALOR) # ordenamiento de menor a mayor
y = np.arange(1, len(x)+1) / len(x)

plt.plot(x, y, marker='.', linestyle='none') # solo puntos
plt.xlabel('Precipitación (mm)')
plt.ylabel('ECDF')
plt.margins(0.02) # Acercar los valores a los ejes X e Y
plt.grid();

# %% [markdown]
# Con la anterior gráfica ECDF podemos observar que aproximadamente el 90% de los datos de precipitación de dicha estación son menores a 10 mm de lluvia.

# %% [markdown]
# **Graficando percentiles**

# %%
percentiles = np.array([2.5, 25, 50, 75, 97.5])

# Compute percentiles: ptiles_vers
ptiles_estac1 = np.percentile(estac_1.VALOR, percentiles)

# Print the result
print(ptiles_estac1)
# Out:
# [ 0.      0.      0.      2.1    16.8675]

# %%
# ECDF: Empirical cumulative distribution function (ECDF)

import numpy as np
x = np.sort(estac_1.VALOR) # ordenamiento de menor a mayor
y = np.arange(1, len(x)+1) / len(x)

plt.plot(x, y, marker='.', linestyle='none') # solo puntos

# Percentiles
plt.plot(ptiles_estac1, percentiles/100, marker='D', color='red', linestyle='none')

plt.xlabel('Precipitación (mm)')
plt.ylabel('ECDF')
plt.margins(0.02) # Acercar los valores a los ejes X e Y
plt.grid();

# %% [markdown]
# ### Ploteando varias series de tiempo

# %%
plt.subplots(1, sharey=True, figsize=(15,7))

plt.title('Estaciones Altamiza y Barrios')
plt.plot(estac_1.FECHA, estac_1.VALOR, c='black', marker='.', linestyle='none', ms=3, label='Estación 1')
plt.plot(estac_2.FECHA, estac_2.VALOR, c='r', marker='.', linestyle='none', ms=3, label='Estación 2') # , alpha=0.3
plt.xlabel('Años'), plt.ylabel('Precipitación (mm)')
plt.legend(loc=1)
plt.grid();

# %% [markdown]
# #### Anotaciones

# %%
estac_2.FECHA[3468]
# Out:
# Timestamp('1983-03-03 00:00:00')

# %%
estac_2[estac_2['VALOR'] == estac_2['VALOR'].max()]['FECHA']
# Out:
# 3468   1983-03-03
# Name: FECHA, dtype: datetime64[ns]

# %%
plt.subplots(1, figsize=(15,7))

plt.plot(estac_1.FECHA, estac_1.VALOR, c='black', marker='.', linestyle='none', ms=3, label='Estación 1')
plt.plot(estac_2.FECHA, estac_2.VALOR, c='r'    , marker='.', linestyle='none', ms=3, label='Estación 2') # , alpha=0.3
plt.xlabel('Años'), plt.ylabel('Precipitación (mm)')

# Anotación
plt.annotate('1983-03-03 Valor: 119.7', 
             xy=(estac_2.FECHA[3468], estac_2['VALOR'].max()), 
             xytext=(estac_2.FECHA[2538], 110), 
             arrowprops={})

plt.legend(loc=1)
plt.grid();

# %% [markdown]
# En caso de plotear diferentes graficas:

# %%
plt.subplots(1, figsize=(15,7))

plt.subplot(121)
plt.title('Estaciones Altamiza')
plt.plot(estac_1.FECHA, estac_1.VALOR, c='black', marker='.', linestyle='none', ms=3, label='Estación 1')
plt.xlabel('Años'), plt.ylabel('Precipitación (mm)')

plt.subplot(122)
plt.title('Estaciones Barrios')
plt.plot(estac_2.FECHA, estac_2.VALOR, c='r', marker='.', linestyle='none', ms=3, label='Estación 2') # , alpha=0.3
plt.xlabel('Años'), plt.ylabel('Precipitación (mm)');

# %% [markdown]
# Nótese que el primero presenta un valor máximo de 70 y más, mientras que la gráfica derecha presenta un valor máximo de 120.

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5))

# Ploteo simple 
ax[0].set_title('Estaciones Altamiza')
ax[0].plot(estac_1.FECHA, estac_1.VALOR, c='black', marker='.', linestyle='none', ms=3, label='Estación 1')
ax[0].set_xlabel('Años')
ax[0].set_ylabel('Precipitación (mm)')

ax[1].set_title('Estaciones Barrios')
ax[1].plot(estac_2.FECHA, estac_2.VALOR, c='r', marker='.', linestyle='none', ms=3, label='Estación 2') # , alpha=0.3
ax[1].set_xlabel('Años')
ax[1].set_ylabel('Precipitación (mm)');

# Al añadir sharey= True indicamos que se comparta el eje Y para ambas gráficas
fig, ax = plt.subplots(1, 2, sharey=True, figsize=(15,5))

ax[0].set_title('Estaciones Altamiza')
ax[0].plot(estac_1.FECHA, estac_1.VALOR, c='black', marker='.', linestyle='none', ms=3, label='Estación 1')
ax[0].set_xlabel('Años')
ax[0].set_ylabel('Precipitación (mm)')

ax[1].set_title('Estaciones Barrios')
ax[1].plot(estac_2.FECHA, estac_2.VALOR, c='r', marker='.', linestyle='none', ms=3, label='Estación 2') # , alpha=0.3
ax[1].set_xlabel('Años')
ax[1].set_ylabel('Precipitación (mm)');

# %% [markdown]
# Vemos la gráfica de la estación Altamiza ha disminuido en altura en relación con la primera gráfica.

# %% [markdown]
# #### Boxplot

# %%
fig, ax = plt.subplots()

ax.boxplot([estac_1.VALOR, estac_2.VALOR])
ax.set_title('Diagrama de Cajas')
ax.set_xticklabels(['Estación 1', 'Estación 2'])
ax.set_ylabel('Precipitación (mm)');

# %% [markdown]
# #### Scatterplot o Diagrama de dispersión
#
# Ojo: Es necesario tener la misma cantidad de valores en X como en Y

# %%
fig, ax = plt.subplots()
ax.scatter(estac_1.VALOR[:6825], estac_2.VALOR, c=estac_1[:6825].index)
ax.set_title('Diagrama de Dispersión')
ax.set_xlabel('Estación 1')
ax.set_ylabel('Estación 2');

# %% [markdown]
# ### Probando Plotly

# %% [markdown]
# ### Conclusiones
#
# 1. Cuando se cambia el formato de fechas de tipo `object` (string) a uno de tipo fecha (date), se agiliza el proceso de visualización (y mejora su interpretación). **De no hacerlo, demorará completar el proceso de visualización con matplotlib y se verán indistinguibles las fechas en el eje X.**

# %%
# 1. Importando archivo csv
import pandas as pd 
estac_2 = pd.read_csv('BARRIOS.csv')

# 2. Convertir a tipo fecha
estac_2.FECHA = pd.to_datetime(estac_2.FECHA) # devuelve a datetime64[ns] (tipo fecha)

# 3. Modificar el formato (convierte a string)
import datetime as dt
estac_2.FECHA = estac_2.FECHA.dt.strftime('%Y/%m/%d') # convierte a string según formato

# 4. Visualización (FECHA en tipo object `string`)
plt.figure(1,figsize=(15,7))

plt.plot(estac_2.FECHA, estac_2.VALOR, c='black', marker='o', ms=5)
plt.title('Precipitación Acumulada Mensual - Estación BARRIOS')
plt.xlabel('Fechas'), plt.ylabel('Precipitación (mm)');
